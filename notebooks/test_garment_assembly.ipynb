# %% [markdown]
# # Test Garment Assembly

# %%
import os
import sys

sys.path.insert(0, os.path.abspath('..'))
from data_process.geometry_utils.obj import read_obj

# %%
data_dir = "../resources/assembly"

# get main bodices
